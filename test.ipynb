# %%
from dotenv import load_dotenv  # .env 파일에 저장된 환경변수를 불러오기 위한 라이브러리
import os  # 운영체제의 환경변수에 접근하기 위한 기본 라이브러리

load_dotenv()  # 현재 디렉토리의 .env 파일을 읽어서 환경변수로 등록

print(os.getenv("OPENAI_API_KEY"))  # 환경변수에서 OPENAI_API_KEY 값을 가져와 출력
# Out:
# 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

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini")
llm.invoke("안녕하세요").content
# Out:
# '안녕하세요! 어떻게 도와드릴까요?'
